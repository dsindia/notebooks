# %%
import numpy as np
import pandas as pd

# %%
oci = pd.read_csv("overseas.csv")
oci
# Out:
#                    Country        Mission        Date  OCI - Registered  \
# 0                SRI LANKA        COLOMBO  08-12-2005                 1
# 1                SRI LANKA        COLOMBO  09-12-2005                 1
# 2                SRI LANKA        COLOMBO  12-12-2005                 1
# 3           UNITED KINGDOM         LONDON  12-12-2005                 1
# 4                   CANADA         OTTAWA  13-12-2005                 1
# 5                   CANADA      VANCOUVER  13-12-2005                 1
# 6                AUSTRALIA         SYDNEY  14-12-2005                 1
# 7                SRI LANKA        COLOMBO  14-12-2005                 1
# 8                    INDIA      MHA DELHI  17-12-2005                35
# 9                    INDIA      MHA DELHI  18-12-2005                 2
# 10               SRI LANKA        COLOMBO  19-12-2005                 5
# 11                     UAE          DUBAI  19-12-2005                 1
# ...

# %%
total = oci.loc(3)
for col in np.arange(4, 9):
    total += oci.loc(col)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-1ab0229d08b2> in <module>()
#       1 total = oci.loc(3)
#       2 for col in np.arange(4, 9):
# ----> 3     total += oci.loc(col)
#
# TypeError: unsupported operand type(s) for +=: '_LocIndexer' and '_LocIndexer'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-c357b8a1f645> in <module>()
# ----> 1 oci.column(2) + oci.column(3)
#
# TypeError: ufunc 'add' did not contain a loop with signature matching types dtype('<U21') dtype('<U21') dtype('<U21')

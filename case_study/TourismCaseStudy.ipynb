# %% [markdown]
# <img src="../dsi.png" style="height:128px;">

# %% [markdown]
# # Case Study: Tourism

# %% [markdown]
# You've learned a lot in the past several sessions. Now, we're going to practice some of what we learned in a *case study*, where we're going to look at data about foreign tourists in India, and see if there's a correlation with the amount of people of Indian origin in these countries.

# %%
from datascience import *
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %% [markdown]
# Here, we read a table from the following source: https://data.gov.in/catalog/number-foreign-tourists-india
# It contains countries, regions, and the amount of tourists from these countries from years between 2001 and 2010.

# %%
tourists = Table().read_table("foreign_tourists.csv")
tourists.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Nationality</th> <th>Region</th> <th>2001</th> <th>2002</th> <th>2003</th> <th>2004</th> <th>2005</th> <th>2006</th> <th>2007</th> <th>2008</th> <th>2009</th> <th>2010</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Canada         </td> <td>NORTH AMERICA            </td> <td>88600 </td> <td>93598 </td> <td>107671</td> <td>135884 </td> <td>157643 </td> <td>176567 </td> <td>208214 </td> <td>222364 </td> <td>224069 </td> <td>242372 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>U.S.A.         </td> <td>NORTH AMERICA            </td> <td>329147</td> <td>348182</td> <td>410803</td> <td>526120 </td> <td>611165 </td> <td>696739 </td> <td>799062 </td> <td>804933 </td> <td>827140 </td> <td>931292 </td>
#         </tr>
#     </tbody>
#         <tr>
# ...

# %%
tourists.where("Nationality", are.equal_to("Total"))
# Out:
# Nationality | Region                    | 2001   | 2002   | 2003   | 2004    | 2005    | 2006    | 2007    | 2008    | 2009    | 2010
# Total       | NORTH AMERICA             | 417747 | 441780 | 518474 | 662004  | 768808  | 873306  | 1007276 | 1027297 | 1051209 | 1173664
# Total       | CENTRAL AND SOUTH AMERICA | 21925  | 17672  | 21654  | 28165   | 35586   | 38745   | 42319   | 43505   | 46604   | 62728
# Total       | WESTERN EUROPE            | 819973 | 726783 | 847966 | 1128297 | 1282119 | 1487271 | 1686083 | 1709525 | 1634042 | 1750342
# Total       |  EASTERN EUROPE           | 38863  | 40628  | 55252  | 82426   | 101445  | 121309  | 152764  | 191110  | 183475  | 227650
# Total       | AFRICA                    | 90962  | 83457  | 93353  | 115493  | 134801  | 142813  | 157485  | 141750  | 164474  | 204525
# Total       |  WEST ASIA                | 96424  | 92562  | 103596 | 122808  | 133821  | 146693  | 171661  | 215542  | 204843  | 235317
# ...

# %%
Ideas: find average amount of tourists from certain region, sort by
